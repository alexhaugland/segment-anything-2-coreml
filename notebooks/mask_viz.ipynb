# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import os
import sys
import matplotlib.pyplot as plt

current_dir = os.path.dirname(os.path.abspath('__file__'))
sys.path.append(os.path.dirname(current_dir))
from sav_dataset.utils.sav_utils import SAVDataset, show_anns, mask_util
from TRAIN import read_video

sav_dir = os.path.expanduser("~/mldata/sav_000")
sav_dataset = SAVDataset(sav_dir)

np.random.seed(123)

video_ids = [f.split('.')[0] for f in os.listdir(sav_dir) if f.endswith('.mp4')]

img, masks, points = read_video(video_ids)

# %%
points[0]
# Out:
# [np.int64(228), np.int64(413)]

# %%
# plot the image and masks side by side
plt.figure(figsize=(20, 10))

# Plot the image with points
plt.subplot(1, 2, 1)
plt.imshow(img)
for point in points:
    plt.scatter(point[0], point[1], color='red', s=50)
plt.axis('off')
plt.title('Image')

# Plot the masks with points
plt.subplot(1, 2, 2)
plt.imshow(masks)
for point in points:
    plt.scatter(point[0], point[1], color='red', s=50)
plt.axis('off')
plt.title('Masks')
# Out:
# Text(0.5, 1.0, 'Masks')

# %%
plt.imshow(masks)
plt.axis('off')
plt.show()

plt.figure(figsize=(10, 10))

# %%
plt.figure(figsize=(10, 10))
plt.imshow(frame)
show_anns(auto_masks, sav_dataset.auto_mask_colors)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1079.5), np.float64(1919.5), np.float64(-0.5))

# %%
from TRAIN import read_batch

# %%
id = video_ids[14:16]

# %%
img, masks, points, labels = read_batch(id)

plt.figure(figsize=(10, 10))
plt.imshow(img)
show_anns(masks, sav_dataset.auto_mask_colors)
plt.axis('off')
# Out:
# There are 443 frames decoded from /home/ahaugland/mldata/sav_000/sav_000500.mp4 (24fps).
# (np.float64(-0.5), np.float64(719.5), np.float64(1279.5), np.float64(-0.5))
